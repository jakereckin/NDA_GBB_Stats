# %%
import pandas as pd
import sportsdataverse.wbb as wbb

# %%
wbb_df = wbb.load_wbb_team_boxscore(seasons=[2022])
# Out:
# ...
# 100%|██████████| 1/1 [00:01<00:00,  1.28s/it]

# %%
pbp = wbb.load_wbb_pbp(seasons=[2022], return_as_pandas=True)
# Out:
# 100%|██████████| 1/1 [00:05<00:00,  5.00s/it]

# %%
sched = wbb.espn_wbb_schedule(return_as_pandas=True)

# %%
sched
# Out:
#             id                                uid               date  \
# 0    401603815  s:40~l:54~e:401603815~c:401603815  2023-11-06T05:00Z
# 1    401603786  s:40~l:54~e:401603786~c:401603786  2023-11-06T05:00Z
# 2    401601163  s:40~l:54~e:401601163~c:401601163  2023-11-06T05:00Z
# 3    401599257  s:40~l:54~e:401599257~c:401599257  2023-11-06T05:00Z
# 4    401599248  s:40~l:54~e:401599248~c:401599248  2023-11-06T05:00Z
# ..         ...                                ...                ...
# 133  401575840  s:40~l:54~e:401575840~c:401575840  2023-11-07T02:00Z
# 134  401598404  s:40~l:54~e:401598404~c:401598404  2023-11-07T02:30Z
# 135  401598146  s:40~l:54~e:401598146~c:401598146  2023-11-07T02:30Z
# 136  401575831  s:40~l:54~e:401575831~c:401575831  2023-11-07T03:00Z
# 137  401577053  s:40~l:54~e:401577053~c:401577053  2023-11-07T04:30Z
#
#      attendance  time_valid  neutral_site  conference_competition  \
# 0             0       False         False                   False
# ...

# %%
data = wbb.espn_wbb_pbp(game_id=401266534)
# Out:
# {'gameId': 401266534,
#  'plays': [{'game_play_number': 1,
#    'id': 401266534101904801,
#    'sequenceNumber': 101904801,
#    'type.id': '572',
#    'type.text': 'LayUpShot',
#    'text': 'Morgan Jones made Layup.',
#    'awayScore': 0,
#    'homeScore': 2,
#    'period.number': 1,
#    'period.displayValue': '1st Quarter',
#    'clock.displayValue': '9:51',
#    'scoringPlay': True,
#    'scoreValue': 2,
#    'team.id': '52',
#    'participants.0.athlete.id': '2984250',
#    'shootingPlay': True,
#    'participants.1.athlete.id': None,
#    'game_id': 401266534,
#    'season': 2021,
#    'seasonType': 2,
#    'homeTeamId': 52,
#    'homeTeamName': 'Florida State',
#    'homeTeamMascot': 'Seminoles',
#    'homeTeamAbbrev': 'FSU',
#    'homeTeamNameAlt': 'Florida St',
#    'awayTeamId': 57,
#    'awayTeamName': 'Florida',
#    'awayTeamMascot': 'Gators',
#    'awayTeamAbbrev': 'FLA',
#    'awayTeamNameAlt': 'Florida',
#    'gameSpread': 2.5,
#    'homeFavorite': True,
# ...

# %%
pd.set_option('display.max_columns', 100)
pbp.columns
# Out:
# Index(['id', 'sequence_number', 'type_id', 'type_text', 'text', 'away_score',
#        'home_score', 'period_number', 'period_display_value',
#        'clock_display_value', 'scoring_play', 'score_value', 'team_id',
#        'wallclock', 'shooting_play', 'coordinate_x_raw', 'coordinate_y_raw',
#        'season', 'season_type', 'away_team_id', 'away_team_name',
#        'away_team_mascot', 'away_team_abbrev', 'away_team_name_alt',
#        'home_team_id', 'home_team_name', 'home_team_mascot',
#        'home_team_abbrev', 'home_team_name_alt', 'home_team_spread',
#        'game_spread', 'home_favorite', 'game_spread_available', 'game_id',
#        'qtr', 'time', 'clock_minutes', 'clock_seconds', 'half', 'game_half',
#        'lead_qtr', 'lead_game_half', 'start_quarter_seconds_remaining',
#        'start_half_seconds_remaining', 'start_game_seconds_remaining',
#        'game_play_number', 'end_quarter_seconds_remaining',
# ...
